# %%
from xarray import open_mfdataset

# %%
ds = open_mfdataset("GL_TS_DB_1301529.nc")
ds
# Out:
# <xarray.Dataset> Size: 65kB
# Dimensions:       (TIME: 1635, DEPTH: 1)
# Coordinates:
#   * TIME          (TIME) datetime64[ns] 13kB 2017-03-15T11:45:00 ... 2017-07-...
#     LATITUDE      (TIME) float32 7kB dask.array<chunksize=(1635,), meta=np.ndarray>
#     LONGITUDE     (TIME) float32 7kB dask.array<chunksize=(1635,), meta=np.ndarray>
#     TRAJECTORY    |S7 7B ...
#     DEPH          (DEPTH) float32 4B dask.array<chunksize=(1,), meta=np.ndarray>
# Dimensions without coordinates: DEPTH
# Data variables:
#     TIME_QC       (TIME) float32 7kB dask.array<chunksize=(1635,), meta=np.ndarray>
#     POSITION_QC   (TIME) float32 7kB dask.array<chunksize=(1635,), meta=np.ndarray>
#     DC_REFERENCE  (TIME) object 13kB dask.array<chunksize=(1635,), meta=np.ndarray>
#     TEMP          (TIME, DEPTH) float32 7kB dask.array<chunksize=(1635, 1), meta=np.ndarray>
#     TEMP_QC       (TIME, DEPTH) float32 7kB dask.array<chunksize=(1635, 1), meta=np.ndarray>
# Attributes: (12/51)
# ...

# %%
subset = ds.sel(TIME=(
    (ds['TIME'].dt.month == 5) &
    (ds['TIME'].dt.day == 2)
))
subset
# Out:
# <xarray.Dataset> Size: 611B
# Dimensions:       (TIME: 15, DEPTH: 1)
# Coordinates:
#   * TIME          (TIME) datetime64[ns] 120B 2017-05-02 ... 2017-05-02T23:00:00
#     LATITUDE      (TIME) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
#     LONGITUDE     (TIME) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
#     TRAJECTORY    |S7 7B ...
#     DEPH          (DEPTH) float32 4B dask.array<chunksize=(1,), meta=np.ndarray>
# Dimensions without coordinates: DEPTH
# Data variables:
#     TIME_QC       (TIME) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
#     POSITION_QC   (TIME) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
#     DC_REFERENCE  (TIME) object 120B dask.array<chunksize=(15,), meta=np.ndarray>
#     TEMP          (TIME, DEPTH) float32 60B dask.array<chunksize=(15, 1), meta=np.ndarray>
#     TEMP_QC       (TIME, DEPTH) float32 60B dask.array<chunksize=(15, 1), meta=np.ndarray>
# Attributes: (12/51)
# ...

# %%
subset.to_netcdf("cmems_2017-05-02_subset.nc")
# Out:
# C:\Users\llierham\mobaxterm\slash\tmp\ipykernel_13528\1519438575.py:1: SerializationWarning: variable DC_REFERENCE has data in the form of a dask array with dtype=object, which means it is being loaded into memory to determine a data type that can be safely stored on disk. To avoid this, coerce this variable to a fixed-size dtype with astype() before saving it.
#   subset.to_netcdf("cmems_2017-05-02_subset.nc")

# %%
ls
# Out:
#  DatentrÃ¤ger in Laufwerk C: ist SYSTEM
#  Volumeseriennummer: 86E5-1CEA
#
#  Verzeichnis von C:\Users\llierham\mobaxterm\github_ll\cdm-testdata\cmems\input
#
# 08.04.2026  13:43    <DIR>          .
# 08.04.2026  13:43    <DIR>          ..
# 08.04.2026  13:41    <DIR>          .ipynb_checkpoints
# 08.04.2026  13:42            64.245 cmems_2017-05-02_subset.nc
# 08.04.2026  13:25            74.423 GL_TS_DB_1301529.nc
# 08.04.2026  13:43           119.082 Untitled.ipynb
#                3 Datei(en),        257.750 Bytes
#                3 Verzeichnis(se), 42.983.768.064 Bytes frei
